# %% [markdown]
# <a href="https://colab.research.google.com/github/subrata0xo/vortex-predict-ai/blob/main/notebooks/Colab_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🌪️ Cyclone AI - 6-Stage Hybrid Pipeline GPU Trainer
# Run this notebook carefully on Google Colab with a free **T4 GPU** to rapidly train your advanced Multi-Modal Transformer model without crashing your local CPU.
#
# **Step 1:** Click `Runtime` → `Change runtime type` at the top. Ensure the Hardware Accelerator is set to **T4 GPU**.
# **Step 2:** Click `Runtime` → `Run all`.
#
# The script will automatically download your GitHub codebase, train the arrays on the GPU in minutes instead of hours, and trigger a download of your `.pt` checkpoint file!

# %%
# !git clone https://github.com/subrata0xo/vortex-predict-ai.git
# %cd vortex-predict-ai
# !pip install -r requirements.txt
# Out:
# Cloning into 'vortex-predict-ai'...
# remote: Enumerating objects: 150, done.
# remote: Counting objects: 100% (150/150), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 150 (delta 63), reused 115 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (150/150), 40.16 MiB | 42.79 MiB/s, done.
# Resolving deltas: 100% (63/63), done.
# /content/vortex-predict-ai/vortex-predict-ai/vortex-predict-ai
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: scipy>=1.11 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (1.16.3)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 8)) (2.10.0+cu128)
# Requirement already satisfied: torchvision>=0.16 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 9)) (0.25.0+cu128)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 12)) (2.32.4)
# Requirement already satisfied: tqdm>=4.66 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 13)) (4.67.3)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 16)) (3.10.0)
# Requirement already satisfied: seaborn>=0.13 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 17)) (0.13.2)
# Requirement already satisfied: pydantic>=2.5 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 20)) (2.12.3)
# Requirement already satisfied: streamlit>=1.28 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 23)) (1.55.0)
# Requirement already satisfied: folium>=0.15 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 24)) (0.20.0)
# Requirement already satisfied: streamlit-folium>=0.15 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 25)) (0.27.0)
# Requirement already satisfied: plotly>=5.18 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 26)) (5.24.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->-r requirements.txt (line 8)) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1->-r requirements.txt (line 8)) (1.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.16->-r requirements.txt (line 9)) (11.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->-r requirements.txt (line 12)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->-r requirements.txt (line 12)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->-r requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->-r requirements.txt (line 12)) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 16)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 16)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 16)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 16)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 16)) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.8->-r requirements.txt (line 16)) (3.3.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5->-r requirements.txt (line 20)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5->-r requirements.txt (line 20)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5->-r requirements.txt (line 20)) (0.4.2)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (3.1.46)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (18.1.0)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (6.5.1)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit>=1.28->-r requirements.txt (line 23)) (6.0.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium>=0.15->-r requirements.txt (line 24)) (0.8.2)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium>=0.15->-r requirements.txt (line 24)) (2025.11.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.28->-r requirements.txt (line 23)) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.28->-r requirements.txt (line 23)) (2.18.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.28->-r requirements.txt (line 23)) (4.0.12)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->-r requirements.txt (line 8)) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0->-r requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->-r requirements.txt (line 8)) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.28->-r requirements.txt (line 23)) (5.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.28->-r requirements.txt (line 23)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.28->-r requirements.txt (line 23)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.28->-r requirements.txt (line 23)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit>=1.28->-r requirements.txt (line 23)) (0.30.0)

# %%
# !python notebooks/06_train_hybrid.py
# Out:
# =================================================================
#   6-STAGE HYBRID PIPELINE: GRIDSAT + ERA5 + TRACK
#   Execution Device : cuda
# =================================================================
#
# Traceback (most recent call last):
#   File "/content/vortex-predict-ai/vortex-predict-ai/vortex-predict-ai/notebooks/06_train_hybrid.py", line 118, in <module>
#     main()
#   File "/content/vortex-predict-ai/vortex-predict-ai/vortex-predict-ai/notebooks/06_train_hybrid.py", line 77, in main
#     loaders = get_loaders(
#               ^^^^^^^^^^^^
#   File "/content/vortex-predict-ai/vortex-predict-ai/vortex-predict-ai/src/features.py", line 163, in get_loaders
#     ds = dataset_cls(split, data_dir=data_dir, **ds_kwargs)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/vortex-predict-ai/vortex-predict-ai/vortex-predict-ai/src/features.py", line 83, in __init__
#     X = np.load(dp / f"{split}_X.npy")
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/numpy/lib/_npyio_impl.py", line 455, in load
#     fid = stack.enter_context(open(os.fspath(file), "rb"))
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'data/processed/train_X.npy'

# %%
from google.colab import files
files.download('checkpoints/hybrid_best.pt')
